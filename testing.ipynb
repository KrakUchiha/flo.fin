# %%
import numpy as np
import matplotlib.pyplot as plt

import random
  

  
def plot_colourline(x,y,c):
    ax = plt.gca()
    for i in np.arange(len(x)-1):
        ax.plot([x[i],x[i+1]], [y[i],y[i+1]], c=c[i])
    return


n = 100
# declaring list
colors_lst = ['red', 'black', 'blue', 'green']
colors = (random.choices(colors_lst, k=n))

x = 1.*np.arange(n)

y = np.random.rand(n)

#prop = x**2

fig = plt.figure(1, figsize=(5,5))
ax  = fig.add_subplot(111)
plot_colourline(x,y,colors)
