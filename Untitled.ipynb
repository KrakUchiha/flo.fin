# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def uniqueish_color(z):
    return z




sns.set_theme(style="darkgrid")

x = [1, 2, 3, 4, 5]
y = [1, 5, 4, 7, 4]
z = ['red', 'red', 'red', 'red','red']

sns.set_color_codes("dark")
for m in range(len(x)):
    sns.lineplot(y=y[m:m+1], x=x[m:m+1], color='red'))
    #sns.lineplot(y=y[m:m+1], x=x[m:m+1], color=uniqueish_color(z[m:m+1]))



#xy = (np.random.random((10, 2)) - 0.5).cumsum(axis=0)

#fig, ax = plt.subplots()
#for start, stop in zip(xy[:-1], xy[1:]):
    #x, y = zip(start, stop)
    #ax.plot(x, y, color=uniqueish_color())
#plt.show()
# Out:
# C:\Users\ROSEMARY\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
